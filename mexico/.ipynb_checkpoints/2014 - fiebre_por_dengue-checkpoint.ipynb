# %%
import pandas as pd

import camelot

import pdfplumber

import os

import re

import numpy as np

# %%
def process_all_pdfs_in_folder(source_path, sink_path, desired_disease):
    year_df = []
    for filename in os.listdir(source_path):
        if filename.lower().endswith('.pdf'):
            pdf_path = os.path.join(source_path, filename)
            print(f"Processando o arquivo: {pdf_path}")
            week_df = extract_and_process_tables(pdf_path, desired_disease, filename)
            year_df.append(week_df)
            
    if year_df:
        concatenated_df = pd.concat(year_df, ignore_index=True)

        pdf_filename = source_path.rsplit('/', 1)[-1]
        print("Salvando")
        csv_filename = os.path.splitext(pdf_filename)[0] + desired_disease + '.csv'
        output_path = os.path.join(sink_path, csv_filename)
        concatenated_df.to_csv(output_path, index=False, encoding='utf-8-sig')
        print(f"Arquivo salvo: {csv_filename}")

# %%
def extract_and_process_tables(pdf_path, desired_disease, filename):
    all_dfs = []
    pdf = pdfplumber.open(pdf_path)

    for page_num in range(len(pdf.pages)):
        try:
            tables = camelot.read_pdf(pdf_path, pages=str(page_num + 1), flavor='stream')

            if tables:
                df = tables[0].df
                page = pdf.pages[page_num]
                table = page.extract_table()
                df_header = pd.DataFrame(table)
                                
                if (not df_header.empty 
                    and df_header.shape[0] > 1  # Verifica se há pelo menos 2 linhas
                    and df_header.shape[1] > 1  # Verifica se há pelo menos 2 colunas
                    and df_header.iloc[0, 1] is not None 
                    and isinstance(df_header.iloc[0, 1], str)
                    and desired_disease in df_header.iloc[0, 1]):  
                    
                    first = None
                    

                    for n in range(4, 10):
                        if df.iloc[n, 0]:
                            first = n
                            break
                            
                    df_all = process_table(df, df_header, filename, first)
                    
                        
                    if not df_all.empty:
                        all_dfs.append(df_all)
#                         print(all_dfs)
                        print(f"Processando a página {page_num + 1} com a tabela desejada.")

        except Exception as e:
            print(f"Erro ao processar a página {page_num + 1}: {e}")

    pdf.close()

    if all_dfs:
        final_df = pd.concat(all_dfs, ignore_index=True)
    else:
        final_df = pd.DataFrame()

    # Salva o DataFrame final em um arquivo CSV
#     pdf_filename = os.path.basename(pdf_path)
#     csv_filename = os.path.splitext(pdf_filename)[0] + '_filtered.csv'
#     output_path = os.path.join('/home/pirata/Documents/projects/epidemic_database/bases', csv_filename)
#     final_df.to_csv(output_path, index=False, encoding='utf-8-sig')

    return final_df

# %%
# Defina a função para processar as tabelas do PDF
def process_table(df, df_header, filename, first):
    
    
    if df.empty or df_header.empty:
        print("DataFrame ou cabeçalho vazio.")
        return pd.DataFrame()  # Retorna um DataFrame vazio se não houver dados
    
    weeknumber = filename[3:5]

    df = df.iloc[first:].reset_index(drop=True)
    df.columns = df.iloc[0]
    df = df[:]

    # df.replace('', np.nan, inplace=True)

    df = df.loc[:, (df != '').any(axis=0)]

    df.dropna(axis=1, how='all')

    col_names = [f'Coluna{i+1}' for i in range(len(df.columns))]
    df.columns = col_names

    for col in col_names[1:len(df.columns)]:
        df[col] = df[col].str.replace(' ', '')

    first_col_name = df.columns[0]
    df = df[~df[first_col_name].str.match(r'^(TOTAL|FUENTE.*|§FUENTE.*)')]

    # # if len(dfx.columns) == 16:

    # #     df = df.drop(['Coluna13','Coluna15'],axis = 1)

    # # else:

    # #     df = df.drop(['Coluna14'],axis = 1)


    indices_para_converter = range(1, len(df.columns))
    for idx in indices_para_converter:
        if idx < len(df.columns):  # Verifica se o índice está dentro dos limites
            df.iloc[:, idx] = pd.to_numeric(df.iloc[:, idx], errors='coerce').fillna(0).astype(int)

    num_col = len(df.columns)


    df1 = df.iloc[:, 0:5].copy()
    if len(df_header) > 1 and len(df_header.columns) > 1:
        df1['disease'] = df_header.iloc[0, 1].replace('\n', ' ')
        df1['year'] = df_header.iloc[1, 1].replace('\n', ' ')
    else:
        df1['disease'] = ''
        df1['year'] = ''


    df1['MF'] = df1.get('Coluna3', 0) + df1.get('Coluna4', 0)  


    df1['Acum_Year'] = int(df_header.iloc[1, 1].replace('\n', ' ')) - 1
    df1['week'] = weeknumber
    # df1['En_Estudio'] = ''

    novos_nomes = [
        'ENTIDAD FEDERATIVA',
        'Sem.',
        'M',
        'F',
        'Acum.'
    ]

    # novos_nomes = [
    #     df_header.iloc[0, 0].replace('\n', ' ') if len(df_header) > 0 and len(df_header.columns) > 0 else '',
    #     df_header.iloc[3, 1].replace('\n', ' ') if len(df_header) > 2 and len(df_header.columns) > 1 else '',
    #     df_header.iloc[4, 2].replace('\n', ' ') if len(df_header) > 3 and len(df_header.columns) > 2 else '',
    #     df_header.iloc[4, 3].replace('\n', ' ') if len(df_header) > 3 and len(df_header.columns) > 3 else '',
    #     'Acum.'
    # ]

    df1.columns = novos_nomes + list(df1.columns[5:])
    column_order = [0, 1, 2, 3, 7, 4, 8, 5, 6, 9]
    df1 = df1.iloc[:, column_order]

    df2 = df.iloc[:, [0] + list(range(5, 8))].copy()

    df2['Acum'] = ''

    if len(df_header) > 0 and len(df_header.columns) > 5:
        df2['disease'] = df_header.iloc[0, 5].replace('\n', ' ')
        df2['year'] = df_header.iloc[1, 5].replace('\n', ' ')
    else:
        df2['disease'] = ''
        df2['year'] = ''


    df2['MF'] = df2.get('Coluna7', 0) + df2.get('Coluna8', 0)

    df2['Acum_Year'] = int(df_header.iloc[1, 5].replace('\n', ' ')) - 1

    df2['week'] = weeknumber



    df2.columns = novos_nomes + list(df2.columns[5:])
    column_order = [0, 1, 2, 3, 7, 4, 8, 5, 6, 9]
    df2 = df2.iloc[:, column_order]




    df3 = df.iloc[:, [0] + list(range(8,len(df.columns)))].copy()

    df3['Acum'] = ''

    if len(df_header) > 0 and len(df_header.columns) > 5:
        df3['disease'] = df_header.iloc[0, 8].replace('\n', ' ')
        df3['year'] = df_header.iloc[1, 8].replace('\n', ' ')
    else:
        df3['disease'] = ''
        df3['year'] = ''

    # # if len(dfx.columns) == 16:

    # #     df3['MF'] = df3.get('Coluna12', 0) + df3.get('Coluna14', 0)

    # # else:

    # #     df3['MF'] = df3.get('Coluna12', 0) + df3.get('Coluna13', 0)


    df3['MF'] = df3.get('Coluna10', 0) + df3.get('Coluna11', 0)


    df3['Acum_Year'] = int(df_header.iloc[1, 8].replace('\n', ' ')) - 1

    df3['week'] = weeknumber

    # df3['En_Estudio'] = ''

    # novos_nomes = [
    #     'ENTIDAD FEDERATIVA',
    #     'Sem.',
    #     'M',
    #     'F',
    #     'Acum.'
    # ]

    # # novos_nomes = [
    # #     df_header.iloc[0, 0].replace('\n', ' ') if len(df_header) > 0 and len(df_header.columns) > 0 else '',
    # #     df_header.iloc[3, 1].replace('\n', ' ') if len(df_header) > 2 and len(df_header.columns) > 1 else '',
    # #     df_header.iloc[4, 2].replace('\n', ' ') if len(df_header) > 3 and len(df_header.columns) > 2 else '',
    # #     df_header.iloc[4, 3].replace('\n', ' ') if len(df_header) > 3 and len(df_header.columns) > 3 else '',
    # #     'Acum.'
    # # ]

    df3.columns = novos_nomes + list(df3.columns[5:])

    column_order = [0, 1, 2, 3, 7, 4, 8, 5, 6, 9]

    df3 = df3.iloc[:, column_order]
    
    df_all = pd.concat([df1, df2, df3], axis=0, ignore_index=True)
    

    return df_all

# %%
source_path = '/home/pirata/Documents/projects/epidemic_database/files/2017'
sink_path = '/home/pirata/Documents/projects/epidemic_database/bases/2017/teste'
desired_disease = 'Dengue'
process_all_pdfs_in_folder(source_path, sink_path, desired_disease)
# Out:
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem43.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem37.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem24.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 34 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem42.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem51.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 2
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 34 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem04.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 34 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem35.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem49.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem14.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 28 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem08.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem03.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 34 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem18.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem28.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 33 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem52.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem25.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 34 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem13.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem05.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem32.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 2
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 34 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem27.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 28 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem20.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 34 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem23.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem02.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 34 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem22.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 34 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem34.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem10.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem09.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem39.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem50.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 34 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem19.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem29.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem41.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem06.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 34 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem11.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem47.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem46.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem38.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem44.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem17.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 34 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem30.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem16.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem21.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 34 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem36.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem26.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem15.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem12.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 34 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem45.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 34 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem40.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 28 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem48.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 34 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem01.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 2
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 28 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem07.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem31.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 2
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Processando o arquivo: /home/pirata/Documents/projects/epidemic_database/files/2017/sem33.pdf
# /home/pirata/.local/lib/python3.8/site-packages/camelot/parsers/stream.py:365: UserWarning: No tables found in table area 1
#   warnings.warn(f"No tables found in table area {table_idx + 1}")
# Processando a página 30 com a tabela desejada.
# Salvando
# Arquivo salvo: 2017Dengue.csv

# %%
filename = 'sem05.pdf'

pdf_path = '/home/pirata/Documents/projects/epidemic_database/files/2014_teste/sem05.pdf'

page_num = 33

pdf = pdfplumber.open(pdf_path)

tables = camelot.read_pdf(pdf_path, pages=str(page_num + 1), flavor='stream')

if tables:
    dfx = tables[0].df
    page = pdf.pages[page_num]
    table = page.extract_table()
    df_header = pd.DataFrame(table)

# %%
first = None

for n in range(4, 10):
    if dfx.iloc[n, 0]:
        first = n
        break
        
        
print(n)
# Out:
# 7

# %%
# weeknumber = re.search(r'-SE(\d+)\.pdf', filename).group(1)

weeknumber = filename[3:5]

df = dfx.iloc[7:].reset_index(drop=True)
df.columns = df.iloc[0]
df = df[:]

# df.replace('', np.nan, inplace=True)

df = df.loc[:, (df != '').any(axis=0)]

df.dropna(axis=1, how='all')

col_names = [f'Coluna{i+1}' for i in range(len(df.columns))]
df.columns = col_names

for col in col_names[1:len(df.columns)]:
    df[col] = df[col].str.replace(' ', '')

first_col_name = df.columns[0]
df = df[~df[first_col_name].str.match(r'^(TOTAL|FUENTE.*|§FUENTE.*)')]

# # if len(dfx.columns) == 16:
    
# #     df = df.drop(['Coluna13','Coluna15'],axis = 1)
    
# # else:
    
# #     df = df.drop(['Coluna14'],axis = 1)


indices_para_converter = range(1, len(df.columns))
for idx in indices_para_converter:
    if idx < len(df.columns):  # Verifica se o índice está dentro dos limites
        df.iloc[:, idx] = pd.to_numeric(df.iloc[:, idx], errors='coerce').fillna(0).astype(int)
        
num_col = len(df.columns)
        

df1 = df.iloc[:, 0:5].copy()
if len(df_header) > 1 and len(df_header.columns) > 1:
    df1['disease'] = df_header.iloc[0, 1].replace('\n', ' ')
    df1['year'] = df_header.iloc[1, 1].replace('\n', ' ')
else:
    df1['disease'] = ''
    df1['year'] = ''
    
    
df1['MF'] = df1.get('Coluna3', 0) + df1.get('Coluna4', 0)  


df1['Acum_Year'] = int(df_header.iloc[1, 1].replace('\n', ' ')) - 1
df1['week'] = weeknumber
# df1['En_Estudio'] = ''

novos_nomes = [
    'ENTIDAD FEDERATIVA',
    'Sem.',
    'M',
    'F',
    'Acum.'
]

# novos_nomes = [
#     df_header.iloc[0, 0].replace('\n', ' ') if len(df_header) > 0 and len(df_header.columns) > 0 else '',
#     df_header.iloc[3, 1].replace('\n', ' ') if len(df_header) > 2 and len(df_header.columns) > 1 else '',
#     df_header.iloc[4, 2].replace('\n', ' ') if len(df_header) > 3 and len(df_header.columns) > 2 else '',
#     df_header.iloc[4, 3].replace('\n', ' ') if len(df_header) > 3 and len(df_header.columns) > 3 else '',
#     'Acum.'
# ]

df1.columns = novos_nomes + list(df1.columns[5:])
column_order = [0, 1, 2, 3, 7, 4, 8, 5, 6, 9]
df1 = df1.iloc[:, column_order]

df2 = df.iloc[:, [0] + list(range(5, 8))].copy()

df2['Acum'] = ''

if len(df_header) > 0 and len(df_header.columns) > 5:
    df2['disease'] = df_header.iloc[0, 5].replace('\n', ' ')
    df2['year'] = df_header.iloc[1, 5].replace('\n', ' ')
else:
    df2['disease'] = ''
    df2['year'] = ''
    
    
df2['MF'] = df2.get('Coluna7', 0) + df2.get('Coluna8', 0)

df2['Acum_Year'] = int(df_header.iloc[1, 5].replace('\n', ' ')) - 1

df2['week'] = weeknumber



df2.columns = novos_nomes + list(df2.columns[5:])
column_order = [0, 1, 2, 3, 7, 4, 8, 5, 6, 9]
df2 = df2.iloc[:, column_order]




df3 = df.iloc[:, [0] + list(range(8,len(df.columns)))].copy()

df3['Acum'] = ''

if len(df_header) > 0 and len(df_header.columns) > 5:
    df3['disease'] = df_header.iloc[0, 8].replace('\n', ' ')
    df3['year'] = df_header.iloc[1, 8].replace('\n', ' ')
else:
    df3['disease'] = ''
    df3['year'] = ''
    
# # if len(dfx.columns) == 16:
    
# #     df3['MF'] = df3.get('Coluna12', 0) + df3.get('Coluna14', 0)
    
# # else:
    
# #     df3['MF'] = df3.get('Coluna12', 0) + df3.get('Coluna13', 0)
    
    
df3['MF'] = df3.get('Coluna10', 0) + df3.get('Coluna11', 0)
    
    
df3['Acum_Year'] = int(df_header.iloc[1, 8].replace('\n', ' ')) - 1

df3['week'] = weeknumber

# df3['En_Estudio'] = ''

# novos_nomes = [
#     'ENTIDAD FEDERATIVA',
#     'Sem.',
#     'M',
#     'F',
#     'Acum.'
# ]

# # novos_nomes = [
# #     df_header.iloc[0, 0].replace('\n', ' ') if len(df_header) > 0 and len(df_header.columns) > 0 else '',
# #     df_header.iloc[3, 1].replace('\n', ' ') if len(df_header) > 2 and len(df_header.columns) > 1 else '',
# #     df_header.iloc[4, 2].replace('\n', ' ') if len(df_header) > 3 and len(df_header.columns) > 2 else '',
# #     df_header.iloc[4, 3].replace('\n', ' ') if len(df_header) > 3 and len(df_header.columns) > 3 else '',
# #     'Acum.'
# # ]

df3.columns = novos_nomes + list(df3.columns[5:])

column_order = [0, 1, 2, 3, 7, 4, 8, 5, 6, 9]

df3 = df3.iloc[:, column_order]


df3
# Out:
#      ENTIDAD FEDERATIVA Sem.  M  F MF Acum.  Acum_Year  \
# 0        Aguascalientes    0  0  0  0             2016
# 1       Baja California    0  0  0  0             2016
# 2   Baja California Sur    0  0  0  0             2016
# 3              Campeche    0  0  0  0             2016
# 4              Coahuila    0  0  0  0             2016
# 5                Colima    1  0  1  1             2016
# 6               Chiapas    1  1  0  1             2016
# 7             Chihuahua    0  0  0  0             2016
# 8      Distrito Federal    0  0  0  0             2016
# 9               Durango    0  0  0  0             2016
# 10           Guanajuato    0  0  0  0             2016
# 11             Guerrero    0  1  1  2             2016
# 12              Hidalgo    0  0  0  0             2016
# 13              Jalisco    0  0  0  0             2016
# 14               México    0  0  0  0             2016
# 15            Michoacán    0  0  0  0             2016
# 16              Morelos    0  0  0  0             2016
# 17              Nayarit    0  0  0  0             2016
# 18           Nuevo León    0  0  0  0             2016
# 19               Oaxaca    0  0  0  0             2016
# 20               Puebla    0  0  0  0             2016
# 21            Querétaro    0  0  0  0             2016
# 22         Quintana Roo    1  0  1  1             2016
# 23      San Luis Potosí    0  0  0  0             2016
# 24              Sinaloa    0  0  0  0             2016
# 25               Sonora    0  0  0  0             2016
# 26              Tabasco    0  0  0  0             2016
# 27           Tamaulipas    1  0  1  1             2016
# 28             Tlaxcala    0  0  0  0             2016
# 29             Veracruz    0  0  0  0             2016
# 30              Yucatán    0  0  0  0             2016
# 31            Zacatecas    0  0  0  0             2016
#
#                           disease  year week
# 0   §DengueGrave CIE-10ª REV. A91  2017   04
# 1   §DengueGrave CIE-10ª REV. A91  2017   04
# 2   §DengueGrave CIE-10ª REV. A91  2017   04
# 3   §DengueGrave CIE-10ª REV. A91  2017   04
# 4   §DengueGrave CIE-10ª REV. A91  2017   04
# 5   §DengueGrave CIE-10ª REV. A91  2017   04
# 6   §DengueGrave CIE-10ª REV. A91  2017   04
# 7   §DengueGrave CIE-10ª REV. A91  2017   04
# 8   §DengueGrave CIE-10ª REV. A91  2017   04
# 9   §DengueGrave CIE-10ª REV. A91  2017   04
# 10  §DengueGrave CIE-10ª REV. A91  2017   04
# 11  §DengueGrave CIE-10ª REV. A91  2017   04
# 12  §DengueGrave CIE-10ª REV. A91  2017   04
# 13  §DengueGrave CIE-10ª REV. A91  2017   04
# 14  §DengueGrave CIE-10ª REV. A91  2017   04
# 15  §DengueGrave CIE-10ª REV. A91  2017   04
# 16  §DengueGrave CIE-10ª REV. A91  2017   04
# 17  §DengueGrave CIE-10ª REV. A91  2017   04
# 18  §DengueGrave CIE-10ª REV. A91  2017   04
# 19  §DengueGrave CIE-10ª REV. A91  2017   04
# 20  §DengueGrave CIE-10ª REV. A91  2017   04
# 21  §DengueGrave CIE-10ª REV. A91  2017   04
# 22  §DengueGrave CIE-10ª REV. A91  2017   04
# 23  §DengueGrave CIE-10ª REV. A91  2017   04
# 24  §DengueGrave CIE-10ª REV. A91  2017   04
# 25  §DengueGrave CIE-10ª REV. A91  2017   04
# 26  §DengueGrave CIE-10ª REV. A91  2017   04
# 27  §DengueGrave CIE-10ª REV. A91  2017   04
# 28  §DengueGrave CIE-10ª REV. A91  2017   04
# 29  §DengueGrave CIE-10ª REV. A91  2017   04
# 30  §DengueGrave CIE-10ª REV. A91  2017   04
# 31  §DengueGrave CIE-10ª REV. A91  2017   04

# %%
len(df.columns)
# Out:
# 14

# %%
display(re.search(r'-SE(\d+)\.pdf', filename).group(1))
# Out:
# '51'

# %%
desired_disease = 'Dengue'

desired_disease in df_header.iloc[0, 1]
# Out:
# True

# %%
len(dfx.columns)
# Out:
# 16

# %%
df_header
# Out:
#                                                   0   \
# 0                                ENTIDAD\nFEDERATIVA
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5  Aguascalientes -\nBaja California -\nBaja Cali...
# 6                                           TOTAL 57
#
#                                     1   \
# 0  §Dengue no Grave\nCIE-10ª REV.\nA90
# 1                                 2017
# 2                          Confirmados
# 3                                 Sem.
# 4                                 None
# 5                                 None
# 6                                 None
#
#                                                   2     3   \
# 0                                               None  None
# 1                                               None  None
# 2                                               None  None
# 3                                              Acum.  None
# 4                                                  M     F
# 5  - -\n- -\n- -\n- -\n1 -\n1 1\n5 5\n- -\n- -\n-...  None
# 6                                              49 62  None
#
#                                                   4   \
# 0                                               None
# 1                                               2016
# 2                                 Confirmados\nAcum.
# 3                                               None
# 4                                               None
# 5  -\n-\n8\n8\n-\n8\n66\n-\n-\n-\n-\n84\n-\n39\n-...
# 6                                                439
#
#                                                   5   \
# 0    §Dengue con Signos de Alarma\nCIE-10ª REV.\nS/C
# 1                                               2017
# 2                                        Confirmados
# 3                                               Sem.
# 4                                               None
# 5  -\n-\n-\n-\n-\n-\n2\n-\n-\n-\n-\n-\n-\n-\n-\n1...
# 6                                                  9
#
#                                                   6     7   \
# 0                                               None  None
# 1                                               None  None
# 2                                               None  None
# 3                                              Acum.  None
# 4                                                  M     F
# 5  - -\n- -\n- -\n- -\n- -\n- -\n3 3\n- -\n- -\n-...  None
# 6                                              16 21  None
#
#                                                   8   \
# 0                    §DengueGrave\nCIE-10ª REV.\nA91
# 1                                               2017
# 2                                        Confirmados
# 3
# 4                                               Sem.
# 5  -\n-\n-\n-\n-\n1\n1\n-\n-\n-\n-\n-\n-\n-\n-\n-...
# 6                                                  4
#
#                                                   9     10
# 0                                               None  None
# 1                                               None  None
# 2                                               None  None
# 3                                              Acum.  None
# 4                                                  M     F
# 5  - -\n- -\n- -\n- -\n- -\n- 1\n1 -\n- -\n- -\n-...  None
# 6                                                2 4  None

# %%
dfx
# Out:
#                      0     1            2   3            4     5   \
# 0            FEDERATIVA
# 1                                     2017             2016
# 2                              Confirmados
# 3                                               Confirmados
# 4                                    Acum.
# 5                        Sem.                         Acum.  Sem.
# 6                                        M   F
# 7        Aguascalientes     -            -   -            -     -
# 8       Baja California     -            -   -            -     -
# 9   Baja California Sur     -            -   -            8     -
# 10             Campeche     -            -   -            8     -
# 11             Coahuila     1            1   -            -     -
# 12               Colima     1            1   1            8     -
# 13              Chiapas     5            5   5           66     2
# 14            Chihuahua     -            -   -            -     -
# 15     Distrito Federal     -            -   -            -     -
# 16              Durango     -            -   -            -     -
# 17           Guanajuato     -            -   -            -     -
# 18             Guerrero     6            2   6           84     -
# 19              Hidalgo     -            -   -            -     -
# 20              Jalisco     2            5   4           39     -
# 21               México     2            1   1            -     -
# 22            Michoacán     6            6  10           28     1
# 23              Morelos     2            1   2            4     3
# 24              Nayarit     5            4   4            8     -
# 25           Nuevo León     4            8   6           14     -
# 26               Oaxaca     -            -   -           12     -
# 27               Puebla     -            -   2           12     -
# 28            Querétaro     -            -   -            -     -
# 29         Quintana Roo     -            1   -           11     1
# 30      San Luis Potosí     1            -   1            3     -
# 31              Sinaloa     6            1   5           16     -
# 32               Sonora     2            1   1           15     -
# 33              Tabasco     -            2   3           43     -
# 34           Tamaulipas    11            6   6            9     -
# 35             Tlaxcala     -            -   -            -     -
# 36             Veracruz     2            4   4           48     2
# 37              Yucatán     1            -   1            3     -
# 38            Zacatecas     -            -   -            -     -
# 39                TOTAL    57           49  62          439     9
#
#              6      7  8   9     10           11     12 13 14
# 0
# 1          2017                             2017
# 2   Confirmados                      Confirmados
# 3
# 4                Acum.                            Acum.
# 5                              Sem.
# 6             M         F                      M         F
# 7                    -      -     -                   -     -
# 8                    -      -     -                   -     -
# 9                    -      -     -                   -     -
# 10                   -      -     -                   -     -
# 11                   -      -     -                   -     -
# 12                   -      -     1                   -     1
# 13                   3      3     1                   1     -
# 14                   -      -     -                   -     -
# 15                   -      -     -                   -     -
# 16                   -      -     -                   -     -
# 17                   -      -     -                   -     -
# 18                   2      4     -                   1     1
# 19                   -      -     -                   -     -
# 20                   2      1     -                   -     -
# 21                   -      -     -                   -     -
# 22                   2      -     -                   -     -
# 23                   4      7     -                   -     -
# 24                   -      1     -                   -     -
# 25                   -      -     -                   -     -
# 26                   -      -     -                   -     -
# 27                   -      1     -                   -     -
# 28                   -      -     -                   -     -
# 29                   -      1     1                   -     1
# 30                   -      -     -                   -     -
# 31                   -      -     -                   -     -
# 32                   -      -     -                   -     -
# 33                   1      -     -                   -     -
# 34                   -      -     1                   -     1
# 35                   -      -     -                   -     -
# 36                   2      2     -                   -     -
# 37                   -      1     -                   -     -
# 38                   -      -     -                   -     -
# 39                  16     21     4                   2     4
